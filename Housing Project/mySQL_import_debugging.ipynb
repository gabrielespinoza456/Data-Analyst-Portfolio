# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='zN63LQ2e',
    database='housing_project',
    allow_local_infile=True
)

# %%
cursor = conn.cursor()

# %%
cursor.execute("SET GLOBAL local_infile=1;")

# %%
csv_path = '/Users/gabriel/Desktop/Data Analyst Portfolio Projects/Zillow_Full_Data.csv'

# %%
query = f"""
LOAD DATA LOCAL INFILE '{csv_path}'
INTO TABLE zillow_data
FIELDS TERMINATED BY ','
OPTIONALLY ENCLOSED BY '"'
LINES TERMINATED BY '\\n'
IGNORE 1 ROWS;
"""

# %%
try:
    cursor.execute(query)
    conn.commit()
    print(f"Success! Loaded {cursor.rowcount} rows")
except Exception as e:
    print("Error: ", e)

cursor.close()
conn.close()
# Out:
# Success! Loaded 8181477 rows
